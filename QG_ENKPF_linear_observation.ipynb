# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os
import numpy as np
import matplotlib.pyplot as plt
import time as tm
from numba import njit
from scipy.fft import dst, idst
from scipy.special import logsumexp

# ============================================================
# USER SETTINGS
# ============================================================
checkpoint_step = 90000
checkpoint_file = f"qg_truth_checkpoint_step_{checkpoint_step}.npz"

assim_config = {
    "ensemble_size": 10,
    "obs_interval": 100,
    "obs_noise_std": 0.1,
    "init_perturb_std": 0.10,
    "inflation": 1.02,
    "num_obs": 36,
    "forecast_steps_after_checkpoint": 10000,
    "random_seed": 42,

    # ---- EnKPF-specific settings ----
    "ess_target_fraction": 0.8,
    "gamma_search_iters": 25,
    "gamma_tol": 1e-4,
    "jitter_after_resample": 0.00,
}

np.random.seed(assim_config["random_seed"])

# ============================================================
# LOAD CHECKPOINT
# ============================================================
if not os.path.exists(checkpoint_file):
    raise FileNotFoundError(
        f"Checkpoint file '{checkpoint_file}' not found. "
        f"Run the truth script first."
    )

data = np.load(checkpoint_file)

wen_truth = data["wen"].copy()
sen_truth = data["sen"].copy()
start_step = int(data["step"])

config = {
    "NX": int(data["NX"]),
    "NY": int(data["NY"]),
    "Re": float(data["Re"]),
    "Ro": float(data["Ro"]),
    "dt": float(data["dt"]),
    "LX": float(data["LX"]),
    "LY": float(data["LY"]),
}

dx = float(data["dx"])
dy = float(data["dy"])
dt = config["dt"]

nx = config["NX"]
ny = config["NY"]

nxi = nx - 1
nyi = ny - 1
state_dim = nxi * nyi

nt_assim = assim_config["forecast_steps_after_checkpoint"]

print(f"Loaded checkpoint from step {start_step}")

# ============================================================
# NUMERICAL ROUTINES
# ============================================================
@njit
def compute_physics_cfl(nx, ny, dx, dy, dt, s):
    u_vel = (s[1:nx, 2:ny+1] - s[1:nx, 0:ny-1]) / (2.0 * dy)
    v_vel = -(s[2:nx+1, 1:ny] - s[0:nx-1, 1:ny]) / (2.0 * dx)
    max_u = np.max(np.abs(u_vel))
    max_v = np.max(np.abs(v_vel))
    return dt * max(max_u/dx, max_v/dy)


def fst_poisson_2d(nx, ny, dx, dy, f):
    f_interior = f[1:nx, 1:ny]
    ft = idst(idst(f_interior, axis=0, type=1), axis=1, type=1)

    i = np.arange(1, nx).reshape(-1, 1)
    j = np.arange(1, ny)

    eigen_x = 2.0 / (dx**2) * (np.cos(np.pi * i / nx) - 1.0)
    eigen_y = 2.0 / (dy**2) * (np.cos(np.pi * j / ny) - 1.0)

    u_coeff = ft / (eigen_x + eigen_y)

    u_interior = dst(dst(u_coeff, axis=0, type=1), axis=1, type=1)
    u = np.zeros((nx + 1, ny + 1))
    u[1:nx, 1:ny] = u_interior
    return u


@njit
def rhs_arakawa(nx, ny, dx, dy, re, ro, w, s, fs):
    gg = 1.0 / (4.0 * dx * dy)
    hh = 1.0 / 3.0

    j1 = gg * ((w[2:nx+1, 1:ny] - w[0:nx-1, 1:ny]) * (s[1:nx, 2:ny+1] - s[1:nx, 0:ny-1]) -
               (w[1:nx, 2:ny+1] - w[1:nx, 0:ny-1]) * (s[2:nx+1, 1:ny] - s[0:nx-1, 1:ny]))

    j2 = gg * (w[2:nx+1, 1:ny] * (s[2:nx+1, 2:ny+1] - s[2:nx+1, 0:ny-1]) -
               w[0:nx-1, 1:ny] * (s[0:nx-1, 2:ny+1] - s[0:nx-1, 0:ny-1]) -
               w[1:nx, 2:ny+1] * (s[2:nx+1, 2:ny+1] - s[0:nx-1, 2:ny+1]) +
               w[1:nx, 0:ny-1] * (s[2:nx+1, 0:ny-1] - s[0:nx-1, 0:ny-1]))

    j3 = gg * (w[2:nx+1, 2:ny+1] * (s[1:nx, 2:ny+1] - s[2:nx+1, 1:ny]) -
               w[0:nx-1, 0:ny-1] * (s[0:nx-1, 1:ny] - s[1:nx, 0:ny-1]) -
               w[0:nx-1, 2:ny+1] * (s[1:nx, 2:ny+1] - s[0:nx-1, 1:ny]) +
               w[2:nx+1, 0:ny-1] * (s[2:nx+1, 1:ny] - s[1:nx, 0:ny-1]))

    jac = (j1 + j2 + j3) * hh

    lap = (1.0/dx**2) * (w[2:nx+1, 1:ny] - 2*w[1:nx, 1:ny] + w[0:nx-1, 1:ny]) + \
          (1.0/dy**2) * (w[1:nx, 2:ny+1] - 2*w[1:nx, 1:ny] + w[1:nx, 0:ny-1])

    cor = (1.0/(2.0*dx)) * (s[2:nx+1, 1:ny] - s[0:nx-1, 1:ny])

    rhs = np.zeros((nx + 1, ny + 1))
    rhs[1:nx, 1:ny] = -jac + lap/re + fs[1:nx, 1:ny] + cor/ro
    return rhs


def rk3_step(wen, sen, fs, config, dx, dy, dt):
    nx = config["NX"]
    ny = config["NY"]
    re = config["Re"]
    ro = config["Ro"]

    r1 = rhs_arakawa(nx, ny, dx, dy, re, ro, wen, sen, fs)
    t1 = wen + dt * r1
    s1 = fst_poisson_2d(nx, ny, dx, dy, t1)

    r2 = rhs_arakawa(nx, ny, dx, dy, re, ro, t1, s1, fs)
    t2 = 0.75 * wen + 0.25 * t1 + 0.25 * dt * r2
    s2 = fst_poisson_2d(nx, ny, dx, dy, t2)

    r3 = rhs_arakawa(nx, ny, dx, dy, re, ro, t2, s2, fs)
    wen_new = (1.0/3.0) * wen + (2.0/3.0) * t2 + (2.0/3.0) * dt * r3
    sen_new = fst_poisson_2d(nx, ny, dx, dy, wen_new)

    return wen_new, sen_new

# ============================================================
# STATE / OBSERVATION HELPERS
# ============================================================
def interior_to_state(w):
    return w[1:nx, 1:ny].reshape(-1).copy()


def state_to_full_w(x):
    w = np.zeros((nx + 1, ny + 1))
    w[1:nx, 1:ny] = x.reshape(nxi, nyi)
    return w


def build_observation_indices(nx, ny, num_obs):
    nside = int(np.ceil(np.sqrt(num_obs)))
    xs = np.linspace(4, nx - 4, nside, dtype=int)
    ys = np.linspace(4, ny - 4, nside, dtype=int)

    pairs = []
    for i in xs:
        for j in ys:
            if 1 <= i <= nx - 1 and 1 <= j <= ny - 1:
                pairs.append((i, j))
    pairs = pairs[:num_obs]

    obs_idx = []
    for i, j in pairs:
        flat_idx = (i - 1) * (ny - 1) + (j - 1)
        obs_idx.append(flat_idx)

    return np.array(obs_idx, dtype=int), pairs


def observe_linear(x, obs_idx):
    return x[obs_idx]


def rel_l2(a, b):
    return np.linalg.norm(a - b) / (np.linalg.norm(a) + 1e-12)

# ============================================================
# ENKPF HELPERS
# ============================================================
def systematic_resample_indices(weights):
    Ne = len(weights)
    positions = (np.arange(Ne) + np.random.rand()) / Ne
    cumsum = np.cumsum(weights)
    cumsum[-1] = 1.0
    return np.searchsorted(cumsum, positions)


def effective_sample_size(weights):
    return 1.0 / np.sum(weights**2)


def compute_tempered_weights(Yf, y_obs, R_inv, gamma):
    """
    Yf    : (m, Ne)
    y_obs : (m,)
    R_inv : (m, m)
    gamma : scalar in [0, 1]
    """
    Ne = Yf.shape[1]
    logw = np.zeros(Ne)

    for e in range(Ne):
        innov = y_obs - Yf[:, e]
        logw[e] = -0.5 * gamma * (innov.T @ R_inv @ innov)

    logw -= logsumexp(logw)
    return np.exp(logw)


def choose_gamma_bisect(Yf, y_obs, R_inv, ess_target, nit=25, tol=1e-4):
    """
    Find gamma in [0,1] so ESS(weights(gamma)) ~= ess_target.
    If gamma=1 still gives ESS >= target, return 1.
    """
    w_full = compute_tempered_weights(Yf, y_obs, R_inv, gamma=1.0)
    ess_full = effective_sample_size(w_full)

    if ess_full >= ess_target:
        return 1.0

    lo, hi = 0.0, 1.0
    for _ in range(nit):
        mid = 0.5 * (lo + hi)
        w_mid = compute_tempered_weights(Yf, y_obs, R_inv, gamma=mid)
        ess_mid = effective_sample_size(w_mid)

        if ess_mid < ess_target:
            hi = mid
        else:
            lo = mid

        if hi - lo < tol:
            break

    return 0.5 * (lo + hi)


def enkpf_analysis(Xf, y_obs, obs_idx, R, inflation=1.0,
                   ess_target_fraction=0.8,
                   gamma_search_iters=25,
                   gamma_tol=1e-4,
                   jitter_after_resample=0.0):
    """
    EnKPF update:
      1) inflate prior ensemble
      2) particle stage with tempered likelihood gamma
      3) resample only if ESS < target
      4) EnKF-style correction with residual likelihood (1-gamma)

    Xf:    (n, Ne)
    y_obs: (m,)
    obs_idx: observed state indices
    R:     (m, m)
    """
    n, Ne = Xf.shape
    m = len(obs_idx)

    # --------------------------------------------------------
    # prior inflation
    # --------------------------------------------------------
    xf_bar = np.mean(Xf, axis=1, keepdims=True)
    Af = Xf - xf_bar
    Xf_inf = xf_bar + inflation * Af

    # --------------------------------------------------------
    # forecasted observations
    # --------------------------------------------------------
    Yf = Xf_inf[obs_idx, :]
    R_inv = np.linalg.inv(R)

    # --------------------------------------------------------
    # choose gamma so ESS tracks target
    # --------------------------------------------------------
    ess_target = ess_target_fraction * Ne
    gamma = choose_gamma_bisect(
        Yf, y_obs, R_inv,
        ess_target=ess_target,
        nit=gamma_search_iters,
        tol=gamma_tol
    )

    # --------------------------------------------------------
    # particle stage
    # --------------------------------------------------------
    if gamma > 1e-12:
        w = compute_tempered_weights(Yf, y_obs, R_inv, gamma)
        ess = effective_sample_size(w)

        if ess < ess_target:
            res_idx = systematic_resample_indices(w)
            Xp = Xf_inf[:, res_idx].copy()
            resampled = True
        else:
            Xp = Xf_inf.copy()
            resampled = False
    else:
        w = np.ones(Ne) / Ne
        ess = Ne
        Xp = Xf_inf.copy()
        resampled = False

    # --------------------------------------------------------
    # optional rejuvenation
    # --------------------------------------------------------
    if jitter_after_resample > 0.0 and resampled:
        xp_bar = np.mean(Xp, axis=1, keepdims=True)
        Ap = Xp - xp_bar
        state_std = np.std(Ap, axis=1, keepdims=True) + 1e-12
        Xp += jitter_after_resample * state_std * np.random.randn(n, Ne)

    # --------------------------------------------------------
    # residual Gaussian update with remaining likelihood
    # --------------------------------------------------------
    gamma_c = min(gamma, 1.0 - 1e-8)
    residual_factor = max(1.0 - gamma_c, 1e-8)
    R_resid = R / residual_factor

    xp_bar = np.mean(Xp, axis=1, keepdims=True)
    Ap = Xp - xp_bar

    Yp = Xp[obs_idx, :]
    yp_bar = np.mean(Yp, axis=1, keepdims=True)
    Dp = Yp - yp_bar

    PHT = (Ap @ Dp.T) / (Ne - 1)
    S = (Dp @ Dp.T) / (Ne - 1) + R_resid
    K = PHT @ np.linalg.inv(S)

    Xa = np.zeros_like(Xp)
    cholR = np.linalg.cholesky(R_resid)

    for e in range(Ne):
        y_pert = y_obs + cholR @ np.random.randn(m)
        Xa[:, e] = Xp[:, e] + K @ (y_pert - Yp[:, e])

    stats = {
        "gamma": gamma,
        "ess": ess,
        "ess_target": ess_target,
        "resampled": resampled,
    }

    return Xa, stats

# ============================================================
# GRID / FORCING
# ============================================================
x_grid = np.linspace(0.0, config["LX"], config["NX"] + 1)
y_grid = np.linspace(-0.5 * config["LY"], 0.5 * config["LY"], config["NY"] + 1)
X, Y = np.meshgrid(x_grid, y_grid, indexing='ij')

fs = np.zeros((nx + 1, ny + 1))
fs[1:-1, 1:-1] = (1.0 / config["Ro"]) * np.sin(np.pi * Y[1:-1, 1:-1])

# ============================================================
# ENKPF INITIALIZATION
# ============================================================
Ne = assim_config["ensemble_size"]
obs_interval = assim_config["obs_interval"]
obs_noise_std = assim_config["obs_noise_std"]
init_perturb_std = assim_config["init_perturb_std"]
inflation = assim_config["inflation"]
num_obs = assim_config["num_obs"]

ess_target_fraction = assim_config["ess_target_fraction"]
gamma_search_iters = assim_config["gamma_search_iters"]
gamma_tol = assim_config["gamma_tol"]
jitter_after_resample = assim_config["jitter_after_resample"]

x_truth0 = interior_to_state(wen_truth)
truth_scale = np.sqrt(np.mean(x_truth0**2))

obs_idx, obs_pairs = build_observation_indices(nx, ny, num_obs)
m = len(obs_idx)
R = (obs_noise_std * truth_scale) ** 2 * np.eye(m)

ensemble_w = []
ensemble_s = []

for e in range(Ne):
    pert = init_perturb_std * truth_scale * np.random.randn(state_dim)
    x0 = x_truth0 + pert
    w0 = state_to_full_w(x0)
    s0 = fst_poisson_2d(nx, ny, dx, dy, w0)
    ensemble_w.append(w0)
    ensemble_s.append(s0)

ensemble_w = np.array(ensemble_w)
ensemble_s = np.array(ensemble_s)

# free drift from ensemble mean
x_free = np.mean(np.array([interior_to_state(w) for w in ensemble_w]), axis=0)
free_w = state_to_full_w(x_free)
free_s = fst_poisson_2d(nx, ny, dx, dy, free_w)

# ============================================================
# DIAGNOSTIC STORAGE
# ============================================================
probe_i = nx // 2
probe_j = ny // 2

t_hist = []
truth_probe = []
drift_probe = []
analysis_probe = []

truth_max = []
drift_max = []
analysis_max = []

drift_err = []
analysis_err = []

assim_times = []
gamma_hist = []
ess_hist = []
resampled_hist = []

forecast_obs_misfit_hist = []
analysis_obs_misfit_hist = []

forecast_state_err_hist = []
analysis_state_err_hist = []

# ============================================================
# MAIN ASSIMILATION RUN
# ============================================================
clock_start = tm.time()
print("Running truth + free drift + EnKPF from checkpoint...")

for n in range(nt_assim):
    step = start_step + n + 1

    # --------------------------------------------------------
    # propagate truth
    # --------------------------------------------------------
    wen_truth, sen_truth = rk3_step(wen_truth, sen_truth, fs, config, dx, dy, dt)

    # --------------------------------------------------------
    # propagate free drift
    # --------------------------------------------------------
    free_w, free_s = rk3_step(free_w, free_s, fs, config, dx, dy, dt)

    # --------------------------------------------------------
    # ensemble forecast
    # --------------------------------------------------------
    for e in range(Ne):
        ensemble_w[e], ensemble_s[e] = rk3_step(
            ensemble_w[e], ensemble_s[e], fs, config, dx, dy, dt
        )

    # --------------------------------------------------------
    # assimilation at correct interval
    # --------------------------------------------------------
    if ((n + 1) % obs_interval) == 0:
        x_truth = interior_to_state(wen_truth)
        y_true = observe_linear(x_truth, obs_idx)
        y_obs = y_true + np.sqrt(np.diag(R)) * np.random.randn(m)

        Xf = np.zeros((state_dim, Ne))
        for e in range(Ne):
            Xf[:, e] = interior_to_state(ensemble_w[e])

        # forecast diagnostics before analysis
        xf_mean = np.mean(Xf, axis=1)
        yf_mean = observe_linear(xf_mean, obs_idx)

        forecast_obs_misfit = np.linalg.norm(y_obs - yf_mean)
        forecast_state_err = rel_l2(x_truth, xf_mean)

        Xa, stats = enkpf_analysis(
            Xf, y_obs, obs_idx, R,
            inflation=inflation,
            ess_target_fraction=ess_target_fraction,
            gamma_search_iters=gamma_search_iters,
            gamma_tol=gamma_tol,
            jitter_after_resample=jitter_after_resample
        )

        # analysis diagnostics after update
        xa_mean = np.mean(Xa, axis=1)
        ya_mean = observe_linear(xa_mean, obs_idx)

        analysis_obs_misfit = np.linalg.norm(y_obs - ya_mean)
        analysis_state_err = rel_l2(x_truth, xa_mean)

        # overwrite ensemble with analysis
        for e in range(Ne):
            ensemble_w[e] = state_to_full_w(Xa[:, e])
            ensemble_s[e] = fst_poisson_2d(nx, ny, dx, dy, ensemble_w[e])

        # store stats
        assim_times.append(step * dt)
        gamma_hist.append(stats["gamma"])
        ess_hist.append(stats["ess"])
        resampled_hist.append(int(stats["resampled"]))

        forecast_obs_misfit_hist.append(forecast_obs_misfit)
        analysis_obs_misfit_hist.append(analysis_obs_misfit)

        forecast_state_err_hist.append(forecast_state_err)
        analysis_state_err_hist.append(analysis_state_err)

        print(
            f"[assim @ step {step}] "
            f"forecast obs misfit = {forecast_obs_misfit:.4e} | "
            f"analysis obs misfit = {analysis_obs_misfit:.4e} | "
            f"forecast state err = {forecast_state_err:.4e} | "
            f"analysis state err = {analysis_state_err:.4e} | "
            f"gamma = {stats['gamma']:.3f} | "
            f"ESS = {stats['ess']:.2f}/{Ne} | "
            f"resampled = {stats['resampled']}"
        )

    # --------------------------------------------------------
    # diagnostics each step
    # --------------------------------------------------------
    w_mean = np.mean(ensemble_w, axis=0)

    t_hist.append(step * dt)
    truth_probe.append(wen_truth[probe_i, probe_j])
    drift_probe.append(free_w[probe_i, probe_j])
    analysis_probe.append(w_mean[probe_i, probe_j])

    truth_max.append(np.max(np.abs(wen_truth)))
    drift_max.append(np.max(np.abs(free_w)))
    analysis_max.append(np.max(np.abs(w_mean)))

    drift_err.append(rel_l2(wen_truth[1:nx, 1:ny], free_w[1:nx, 1:ny]))
    analysis_err.append(rel_l2(wen_truth[1:nx, 1:ny], w_mean[1:nx, 1:ny]))

    if (n + 1) % 500 == 0:
        msg = (
            f"Assim step {n+1}/{nt_assim} | "
            f"drift err = {drift_err[-1]:.4e} | "
            f"analysis err = {analysis_err[-1]:.4e}"
        )
        if len(gamma_hist) > 0:
            msg += (
                f" | last gamma = {gamma_hist[-1]:.3f}"
                f" | last ESS = {ess_hist[-1]:.2f}"
                f" | last resampled = {bool(resampled_hist[-1])}"
            )
        print(msg)

print(f"Assimilation run time: {tm.time() - clock_start:.2f} s")

# ============================================================
# FINAL FIELD SNAPSHOTS
# ============================================================
w_mean_final = np.mean(ensemble_w, axis=0)
s_mean_final = fst_poisson_2d(nx, ny, dx, dy, w_mean_final)

# ============================================================
# PLOTTING
# ============================================================
# 1. Probe trajectory
fig1, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(t_hist, truth_probe, linewidth=2, label='Truth')
ax1.plot(t_hist, drift_probe, linewidth=2, linestyle='--', label='Drifted forecast')
ax1.plot(t_hist, analysis_probe, linewidth=2, label='EnKPF corrected')
for t_assim in assim_times:
    ax1.axvline(t_assim, color='gray', alpha=0.08, linewidth=0.5)
ax1.set_title(rf"Probe trajectory at $(i,j)=({probe_i},{probe_j})$")
ax1.set_xlabel("Time (s)")
ax1.set_ylabel(r"$\omega(i,j)$")
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(loc='upper right')
plt.tight_layout()

# 2. Max |omega|
fig2, ax2 = plt.subplots(figsize=(10, 5))
ax2.plot(t_hist, truth_max, linewidth=2, label='Truth')
ax2.plot(t_hist, drift_max, linewidth=2, linestyle='--', label='Drifted forecast')
ax2.plot(t_hist, analysis_max, linewidth=2, label='EnKPF corrected')
ax2.set_title(r"Trajectory comparison using max $|\omega|$")
ax2.set_xlabel("Time (s)")
ax2.set_ylabel(r"Max $|\omega|$")
ax2.grid(True, linestyle='--', alpha=0.5)
ax2.legend(loc='upper right')
plt.tight_layout()

# 3. Relative state error
fig3, ax3 = plt.subplots(figsize=(10, 5))
ax3.plot(t_hist, drift_err, linewidth=2, linestyle='--', label='Drifted rel. $L_2$ error')
ax3.plot(t_hist, analysis_err, linewidth=2, label='EnKPF rel. $L_2$ error')
ax3.set_title(r"Error reduction due to EnKPF")
ax3.set_xlabel("Time (s)")
ax3.set_ylabel(r"Relative $L_2$ error")
ax3.grid(True, linestyle='--', alpha=0.5)
ax3.legend(loc='upper right')
plt.tight_layout()

# 4. Final vorticity fields
fig4, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

axes[0].contourf(X, Y, wen_truth, 100, cmap='RdBu_r')
axes[0].set_title("Truth final vorticity")
axes[0].set_aspect('equal')
axes[0].set_ylabel("y")
axes[0].set_xlabel("x")

axes[1].contourf(X, Y, free_w, 100, cmap='RdBu_r')
axes[1].set_title("Drifted final vorticity")
axes[1].set_aspect('equal')
axes[1].set_xlabel("x")

axes[2].contourf(X, Y, w_mean_final, 100, cmap='RdBu_r')
axes[2].set_title("EnKPF corrected final vorticity")
axes[2].set_aspect('equal')
axes[2].set_xlabel("x")

plt.tight_layout()

# 5. Final streamfunction fields
fig5, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

axes[0].contourf(X, Y, sen_truth, 100, cmap='viridis')
axes[0].set_title("Truth final streamfunction")
axes[0].set_aspect('equal')
axes[0].set_ylabel("y")
axes[0].set_xlabel("x")

axes[1].contourf(X, Y, free_s, 100, cmap='viridis')
axes[1].set_title("Drifted final streamfunction")
axes[1].set_aspect('equal')
axes[1].set_xlabel("x")

axes[2].contourf(X, Y, s_mean_final, 100, cmap='viridis')
axes[2].set_title("EnKPF corrected streamfunction")
axes[2].set_aspect('equal')
axes[2].set_xlabel("x")

plt.tight_layout()

# 6. EnKPF tempering diagnostics
if len(gamma_hist) > 0:
    fig6, ax6 = plt.subplots(1, 2, figsize=(12, 4))

    ax6[0].plot(np.arange(1, len(gamma_hist) + 1), gamma_hist, marker='o')
    ax6[0].set_title("EnKPF tempering parameter $\\gamma$")
    ax6[0].set_xlabel("Assimilation index")
    ax6[0].set_ylabel("$\\gamma$")
    ax6[0].grid(True, linestyle='--', alpha=0.5)

    ax6[1].plot(np.arange(1, len(ess_hist) + 1), ess_hist, marker='s')
    ax6[1].axhline(assim_config["ess_target_fraction"] * Ne, color='r',
                   linestyle='--', label='ESS target')
    ax6[1].set_title("Effective sample size")
    ax6[1].set_xlabel("Assimilation index")
    ax6[1].set_ylabel("ESS")
    ax6[1].grid(True, linestyle='--', alpha=0.5)
    ax6[1].legend()

    plt.tight_layout()

# 7. Observation-space and state-space improvement diagnostics
if len(forecast_obs_misfit_hist) > 0:
    fig7, ax7 = plt.subplots(1, 2, figsize=(13, 4))

    ax7[0].plot(forecast_obs_misfit_hist, linewidth=2, label='Forecast obs misfit')
    ax7[0].plot(analysis_obs_misfit_hist, linewidth=2, label='Analysis obs misfit')
    ax7[0].set_title("Observation-space misfit at assimilation times")
    ax7[0].set_xlabel("Assimilation index")
    ax7[0].set_ylabel(r"$\|y_{obs} - Hx\|_2$")
    ax7[0].grid(True, linestyle='--', alpha=0.5)
    ax7[0].legend(loc='upper right')

    ax7[1].plot(forecast_state_err_hist, linewidth=2, label='Forecast state error')
    ax7[1].plot(analysis_state_err_hist, linewidth=2, label='Analysis state error')
    ax7[1].set_title("State-space error at assimilation times")
    ax7[1].set_xlabel("Assimilation index")
    ax7[1].set_ylabel(r"Relative $L_2$ error")
    ax7[1].grid(True, linestyle='--', alpha=0.5)
    ax7[1].legend(loc='upper right')

    plt.tight_layout()

plt.show()
# Out:
# Loaded checkpoint from step 90000
# Running truth + free drift + EnKPF from checkpoint...
# [assim @ step 90100] forecast obs misfit = 5.2969e+01 | analysis obs misfit = 5.1976e+01 | forecast state err = 1.7410e-02 | analysis state err = 1.9789e-02 | gamma = 0.458 | ESS = 8.00/10 | resampled = False
# [assim @ step 90200] forecast obs misfit = 7.6486e+01 | analysis obs misfit = 7.2754e+01 | forecast state err = 1.3607e-02 | analysis state err = 2.6822e-02 | gamma = 0.200 | ESS = 8.00/10 | resampled = True
# [assim @ step 90300] forecast obs misfit = 6.9166e+01 | analysis obs misfit = 6.8405e+01 | forecast state err = 2.1622e-02 | analysis state err = 2.1180e-02 | gamma = 0.621 | ESS = 8.00/10 | resampled = True
# [assim @ step 90400] forecast obs misfit = 5.6528e+01 | analysis obs misfit = 5.6528e+01 | forecast state err = 1.8929e-02 | analysis state err = 1.8929e-02 | gamma = 1.000 | ESS = 8.37/10 | resampled = False
# [assim @ step 90500] forecast obs misfit = 7.4342e+01 | analysis obs misfit = 7.4262e+01 | forecast state err = 1.8231e-02 | analysis state err = 1.8305e-02 | gamma = 0.942 | ESS = 8.00/10 | resampled = False
# Assim step 500/10000 | drift err = 7.3381e-03 | analysis err = 1.8305e-02 | last gamma = 0.942 | last ESS = 8.00 | last resampled = False
# [assim @ step 90600] forecast obs misfit = 6.1103e+01 | analysis obs misfit = 6.0771e+01 | forecast state err = 1.8740e-02 | analysis state err = 1.7342e-02 | gamma = 0.958 | ESS = 8.00/10 | resampled = True
# [assim @ step 90700] forecast obs misfit = 5.7700e+01 | analysis obs misfit = 5.6965e+01 | forecast state err = 1.8195e-02 | analysis state err = 1.5425e-02 | gamma = 0.684 | ESS = 8.00/10 | resampled = True
# [assim @ step 90800] forecast obs misfit = 7.2424e+01 | analysis obs misfit = 7.1585e+01 | forecast state err = 1.6369e-02 | analysis state err = 1.4338e-02 | gamma = 0.709 | ESS = 8.00/10 | resampled = True
# [assim @ step 90900] forecast obs misfit = 6.2532e+01 | analysis obs misfit = 6.2610e+01 | forecast state err = 1.5242e-02 | analysis state err = 1.5648e-02 | gamma = 0.712 | ESS = 8.00/10 | resampled = False
# [assim @ step 91000] forecast obs misfit = 6.8048e+01 | analysis obs misfit = 6.8035e+01 | forecast state err = 1.7033e-02 | analysis state err = 1.7038e-02 | gamma = 0.706 | ESS = 8.00/10 | resampled = False
# Assim step 1000/10000 | drift err = 6.9309e-03 | analysis err = 1.7038e-02 | last gamma = 0.706 | last ESS = 8.00 | last resampled = False
# [assim @ step 91100] forecast obs misfit = 6.2338e+01 | analysis obs misfit = 5.8463e+01 | forecast state err = 1.8703e-02 | analysis state err = 1.5202e-02 | gamma = 0.256 | ESS = 8.00/10 | resampled = False
# [assim @ step 91200] forecast obs misfit = 5.1480e+01 | analysis obs misfit = 5.1200e+01 | forecast state err = 1.6008e-02 | analysis state err = 1.5883e-02 | gamma = 0.806 | ESS = 8.00/10 | resampled = False
# [assim @ step 91300] forecast obs misfit = 5.9816e+01 | analysis obs misfit = 5.9816e+01 | forecast state err = 1.6663e-02 | analysis state err = 1.6663e-02 | gamma = 1.000 | ESS = 8.53/10 | resampled = False
# [assim @ step 91400] forecast obs misfit = 6.7028e+01 | analysis obs misfit = 6.7028e+01 | forecast state err = 1.7295e-02 | analysis state err = 1.7295e-02 | gamma = 1.000 | ESS = 8.94/10 | resampled = False
# [assim @ step 91500] forecast obs misfit = 6.9583e+01 | analysis obs misfit = 6.8801e+01 | forecast state err = 1.7771e-02 | analysis state err = 1.8120e-02 | gamma = 0.752 | ESS = 8.00/10 | resampled = True
# Assim step 1500/10000 | drift err = 7.9511e-03 | analysis err = 1.8120e-02 | last gamma = 0.752 | last ESS = 8.00 | last resampled = True
# [assim @ step 91600] forecast obs misfit = 6.2583e+01 | analysis obs misfit = 6.2583e+01 | forecast state err = 1.8871e-02 | analysis state err = 1.8871e-02 | gamma = 1.000 | ESS = 9.21/10 | resampled = False
# [assim @ step 91700] forecast obs misfit = 5.4644e+01 | analysis obs misfit = 5.4644e+01 | forecast state err = 1.9381e-02 | analysis state err = 1.9381e-02 | gamma = 1.000 | ESS = 9.07/10 | resampled = False
# [assim @ step 91800] forecast obs misfit = 6.2956e+01 | analysis obs misfit = 6.2844e+01 | forecast state err = 1.9655e-02 | analysis state err = 1.9905e-02 | gamma = 0.894 | ESS = 8.00/10 | resampled = False
# [assim @ step 91900] forecast obs misfit = 5.8385e+01 | analysis obs misfit = 5.7961e+01 | forecast state err = 2.0159e-02 | analysis state err = 2.0653e-02 | gamma = 0.990 | ESS = 8.00/10 | resampled = True
# [assim @ step 92000] forecast obs misfit = 6.1125e+01 | analysis obs misfit = 5.9515e+01 | forecast state err = 2.1171e-02 | analysis state err = 1.7877e-02 | gamma = 0.387 | ESS = 8.00/10 | resampled = False
# Assim step 2000/10000 | drift err = 9.0862e-03 | analysis err = 1.7877e-02 | last gamma = 0.387 | last ESS = 8.00 | last resampled = False
# [assim @ step 92100] forecast obs misfit = 6.2900e+01 | analysis obs misfit = 5.8141e+01 | forecast state err = 1.8481e-02 | analysis state err = 1.8369e-02 | gamma = 0.236 | ESS = 8.00/10 | resampled = True
# [assim @ step 92200] forecast obs misfit = 7.0005e+01 | analysis obs misfit = 6.8430e+01 | forecast state err = 1.8673e-02 | analysis state err = 1.7860e-02 | gamma = 0.453 | ESS = 8.00/10 | resampled = True
# [assim @ step 92300] forecast obs misfit = 6.7107e+01 | analysis obs misfit = 6.7107e+01 | forecast state err = 1.9164e-02 | analysis state err = 1.9164e-02 | gamma = 1.000 | ESS = 9.44/10 | resampled = False
# [assim @ step 92400] forecast obs misfit = 6.1224e+01 | analysis obs misfit = 6.1224e+01 | forecast state err = 2.1139e-02 | analysis state err = 2.1139e-02 | gamma = 1.000 | ESS = 9.65/10 | resampled = False
# [assim @ step 92500] forecast obs misfit = 6.7582e+01 | analysis obs misfit = 6.7582e+01 | forecast state err = 2.3592e-02 | analysis state err = 2.3592e-02 | gamma = 1.000 | ESS = 9.16/10 | resampled = False
# Assim step 2500/10000 | drift err = 1.1753e-02 | analysis err = 2.3592e-02 | last gamma = 1.000 | last ESS = 9.16 | last resampled = False
# [assim @ step 92600] forecast obs misfit = 7.1228e+01 | analysis obs misfit = 7.1301e+01 | forecast state err = 2.6142e-02 | analysis state err = 2.5964e-02 | gamma = 0.980 | ESS = 8.00/10 | resampled = False
# [assim @ step 92700] forecast obs misfit = 6.1903e+01 | analysis obs misfit = 6.0838e+01 | forecast state err = 2.8352e-02 | analysis state err = 3.1106e-02 | gamma = 0.614 | ESS = 8.00/10 | resampled = True
# [assim @ step 92800] forecast obs misfit = 7.8474e+01 | analysis obs misfit = 7.8474e+01 | forecast state err = 3.2216e-02 | analysis state err = 3.2216e-02 | gamma = 1.000 | ESS = 9.41/10 | resampled = False
# [assim @ step 92900] forecast obs misfit = 6.6332e+01 | analysis obs misfit = 6.5606e+01 | forecast state err = 3.3102e-02 | analysis state err = 3.4497e-02 | gamma = 0.668 | ESS = 8.00/10 | resampled = False
# [assim @ step 93000] forecast obs misfit = 6.8928e+01 | analysis obs misfit = 6.8713e+01 | forecast state err = 3.5032e-02 | analysis state err = 3.6315e-02 | gamma = 0.937 | ESS = 8.00/10 | resampled = True
# Assim step 3000/10000 | drift err = 1.3656e-02 | analysis err = 3.6315e-02 | last gamma = 0.937 | last ESS = 8.00 | last resampled = True
# [assim @ step 93100] forecast obs misfit = 6.9737e+01 | analysis obs misfit = 6.8552e+01 | forecast state err = 3.6640e-02 | analysis state err = 3.4988e-02 | gamma = 0.540 | ESS = 8.00/10 | resampled = True
# [assim @ step 93200] forecast obs misfit = 7.0101e+01 | analysis obs misfit = 6.9198e+01 | forecast state err = 3.5569e-02 | analysis state err = 3.7542e-02 | gamma = 0.524 | ESS = 8.00/10 | resampled = False
# [assim @ step 93300] forecast obs misfit = 6.1642e+01 | analysis obs misfit = 6.1642e+01 | forecast state err = 3.7109e-02 | analysis state err = 3.7109e-02 | gamma = 1.000 | ESS = 9.48/10 | resampled = False
# [assim @ step 93400] forecast obs misfit = 6.0678e+01 | analysis obs misfit = 5.7677e+01 | forecast state err = 3.5888e-02 | analysis state err = 3.0246e-02 | gamma = 0.347 | ESS = 8.00/10 | resampled = True
# [assim @ step 93500] forecast obs misfit = 7.5507e+01 | analysis obs misfit = 6.9081e+01 | forecast state err = 2.9707e-02 | analysis state err = 3.1348e-02 | gamma = 0.178 | ESS = 8.00/10 | resampled = True
# Assim step 3500/10000 | drift err = 2.2222e-02 | analysis err = 3.1348e-02 | last gamma = 0.178 | last ESS = 8.00 | last resampled = True
# [assim @ step 93600] forecast obs misfit = 7.1457e+01 | analysis obs misfit = 7.1457e+01 | forecast state err = 3.2239e-02 | analysis state err = 3.2239e-02 | gamma = 1.000 | ESS = 9.17/10 | resampled = False
# [assim @ step 93700] forecast obs misfit = 7.3264e+01 | analysis obs misfit = 7.3020e+01 | forecast state err = 3.3536e-02 | analysis state err = 3.2162e-02 | gamma = 0.800 | ESS = 8.00/10 | resampled = False
# [assim @ step 93800] forecast obs misfit = 5.8978e+01 | analysis obs misfit = 5.7865e+01 | forecast state err = 3.3484e-02 | analysis state err = 2.8676e-02 | gamma = 0.612 | ESS = 8.00/10 | resampled = True
# [assim @ step 93900] forecast obs misfit = 5.9509e+01 | analysis obs misfit = 5.9509e+01 | forecast state err = 2.8970e-02 | analysis state err = 2.8970e-02 | gamma = 1.000 | ESS = 9.54/10 | resampled = False
# [assim @ step 94000] forecast obs misfit = 5.3716e+01 | analysis obs misfit = 5.3026e+01 | forecast state err = 2.9184e-02 | analysis state err = 2.8865e-02 | gamma = 0.491 | ESS = 8.00/10 | resampled = False
# Assim step 4000/10000 | drift err = 3.3358e-02 | analysis err = 2.8865e-02 | last gamma = 0.491 | last ESS = 8.00 | last resampled = False
# [assim @ step 94100] forecast obs misfit = 6.6581e+01 | analysis obs misfit = 6.6090e+01 | forecast state err = 3.0082e-02 | analysis state err = 3.1769e-02 | gamma = 0.675 | ESS = 8.00/10 | resampled = False
# [assim @ step 94200] forecast obs misfit = 5.6747e+01 | analysis obs misfit = 5.6797e+01 | forecast state err = 3.3574e-02 | analysis state err = 3.4798e-02 | gamma = 0.704 | ESS = 8.00/10 | resampled = False
# [assim @ step 94300] forecast obs misfit = 6.1994e+01 | analysis obs misfit = 6.1815e+01 | forecast state err = 3.6138e-02 | analysis state err = 4.1061e-02 | gamma = 0.671 | ESS = 8.00/10 | resampled = False
# [assim @ step 94400] forecast obs misfit = 6.9460e+01 | analysis obs misfit = 6.6814e+01 | forecast state err = 4.2482e-02 | analysis state err = 3.3070e-02 | gamma = 0.273 | ESS = 8.00/10 | resampled = True
# [assim @ step 94500] forecast obs misfit = 7.5225e+01 | analysis obs misfit = 7.3822e+01 | forecast state err = 3.3525e-02 | analysis state err = 4.2532e-02 | gamma = 0.513 | ESS = 8.00/10 | resampled = True
# Assim step 4500/10000 | drift err = 4.2033e-02 | analysis err = 4.2532e-02 | last gamma = 0.513 | last ESS = 8.00 | last resampled = True
# [assim @ step 94600] forecast obs misfit = 7.6022e+01 | analysis obs misfit = 7.1673e+01 | forecast state err = 4.1679e-02 | analysis state err = 3.3283e-02 | gamma = 0.175 | ESS = 8.00/10 | resampled = False
# [assim @ step 94700] forecast obs misfit = 8.5815e+01 | analysis obs misfit = 8.4071e+01 | forecast state err = 3.2914e-02 | analysis state err = 3.1754e-02 | gamma = 0.434 | ESS = 8.00/10 | resampled = False
# [assim @ step 94800] forecast obs misfit = 6.0240e+01 | analysis obs misfit = 6.0133e+01 | forecast state err = 3.1406e-02 | analysis state err = 3.1493e-02 | gamma = 0.782 | ESS = 8.00/10 | resampled = False
# [assim @ step 94900] forecast obs misfit = 7.0611e+01 | analysis obs misfit = 7.0611e+01 | forecast state err = 3.1604e-02 | analysis state err = 3.1604e-02 | gamma = 1.000 | ESS = 8.82/10 | resampled = False
# [assim @ step 95000] forecast obs misfit = 7.0061e+01 | analysis obs misfit = 7.0061e+01 | forecast state err = 3.2925e-02 | analysis state err = 3.2925e-02 | gamma = 1.000 | ESS = 9.22/10 | resampled = False
# Assim step 5000/10000 | drift err = 3.7410e-02 | analysis err = 3.2925e-02 | last gamma = 1.000 | last ESS = 9.22 | last resampled = False
# [assim @ step 95100] forecast obs misfit = 6.8608e+01 | analysis obs misfit = 6.8608e+01 | forecast state err = 3.5993e-02 | analysis state err = 3.5993e-02 | gamma = 1.000 | ESS = 9.33/10 | resampled = False
# [assim @ step 95200] forecast obs misfit = 6.9706e+01 | analysis obs misfit = 6.9152e+01 | forecast state err = 4.0995e-02 | analysis state err = 4.0984e-02 | gamma = 0.625 | ESS = 8.00/10 | resampled = False
# [assim @ step 95300] forecast obs misfit = 5.2624e+01 | analysis obs misfit = 5.2624e+01 | forecast state err = 4.6851e-02 | analysis state err = 4.6851e-02 | gamma = 1.000 | ESS = 8.89/10 | resampled = False
# [assim @ step 95400] forecast obs misfit = 6.5396e+01 | analysis obs misfit = 6.5396e+01 | forecast state err = 5.1497e-02 | analysis state err = 5.1497e-02 | gamma = 1.000 | ESS = 8.04/10 | resampled = False
# [assim @ step 95500] forecast obs misfit = 5.3909e+01 | analysis obs misfit = 5.3909e+01 | forecast state err = 5.3219e-02 | analysis state err = 5.3219e-02 | gamma = 1.000 | ESS = 9.18/10 | resampled = False
# Assim step 5500/10000 | drift err = 5.8414e-02 | analysis err = 5.3219e-02 | last gamma = 1.000 | last ESS = 9.18 | last resampled = False
# [assim @ step 95600] forecast obs misfit = 7.0704e+01 | analysis obs misfit = 6.9975e+01 | forecast state err = 5.2937e-02 | analysis state err = 5.2417e-02 | gamma = 0.530 | ESS = 8.00/10 | resampled = False
# [assim @ step 95700] forecast obs misfit = 9.0832e+01 | analysis obs misfit = 8.6381e+01 | forecast state err = 5.2525e-02 | analysis state err = 4.5710e-02 | gamma = 0.233 | ESS = 8.00/10 | resampled = True
# [assim @ step 95800] forecast obs misfit = 7.1102e+01 | analysis obs misfit = 7.0017e+01 | forecast state err = 4.7477e-02 | analysis state err = 4.7669e-02 | gamma = 0.434 | ESS = 8.00/10 | resampled = True
# [assim @ step 95900] forecast obs misfit = 7.8828e+01 | analysis obs misfit = 7.6126e+01 | forecast state err = 5.0815e-02 | analysis state err = 4.9869e-02 | gamma = 0.268 | ESS = 8.00/10 | resampled = True
# [assim @ step 96000] forecast obs misfit = 7.6116e+01 | analysis obs misfit = 7.6116e+01 | forecast state err = 5.4316e-02 | analysis state err = 5.4316e-02 | gamma = 1.000 | ESS = 8.76/10 | resampled = False
# Assim step 6000/10000 | drift err = 7.8946e-02 | analysis err = 5.4316e-02 | last gamma = 1.000 | last ESS = 8.76 | last resampled = False
# [assim @ step 96100] forecast obs misfit = 5.8852e+01 | analysis obs misfit = 5.8852e+01 | forecast state err = 5.9002e-02 | analysis state err = 5.9002e-02 | gamma = 1.000 | ESS = 8.75/10 | resampled = False
# [assim @ step 96200] forecast obs misfit = 6.9358e+01 | analysis obs misfit = 6.9113e+01 | forecast state err = 6.3315e-02 | analysis state err = 6.3544e-02 | gamma = 0.873 | ESS = 8.00/10 | resampled = False
# [assim @ step 96300] forecast obs misfit = 6.4281e+01 | analysis obs misfit = 6.3620e+01 | forecast state err = 6.8104e-02 | analysis state err = 6.6103e-02 | gamma = 0.539 | ESS = 8.00/10 | resampled = False
# [assim @ step 96400] forecast obs misfit = 7.7030e+01 | analysis obs misfit = 7.3270e+01 | forecast state err = 7.1073e-02 | analysis state err = 6.5724e-02 | gamma = 0.280 | ESS = 8.00/10 | resampled = True
# [assim @ step 96500] forecast obs misfit = 9.3860e+01 | analysis obs misfit = 9.1229e+01 | forecast state err = 6.9653e-02 | analysis state err = 6.5326e-02 | gamma = 0.312 | ESS = 8.00/10 | resampled = True
# Assim step 6500/10000 | drift err = 1.1761e-01 | analysis err = 6.5326e-02 | last gamma = 0.312 | last ESS = 8.00 | last resampled = True
# [assim @ step 96600] forecast obs misfit = 9.8123e+01 | analysis obs misfit = 8.6437e+01 | forecast state err = 6.7571e-02 | analysis state err = 6.0678e-02 | gamma = 0.133 | ESS = 8.00/10 | resampled = False
# [assim @ step 96700] forecast obs misfit = 6.0994e+01 | analysis obs misfit = 5.9073e+01 | forecast state err = 5.9621e-02 | analysis state err = 5.8295e-02 | gamma = 0.387 | ESS = 8.00/10 | resampled = False
# [assim @ step 96800] forecast obs misfit = 5.9603e+01 | analysis obs misfit = 5.9603e+01 | forecast state err = 5.7264e-02 | analysis state err = 5.7264e-02 | gamma = 1.000 | ESS = 8.91/10 | resampled = False
# [assim @ step 96900] forecast obs misfit = 7.0885e+01 | analysis obs misfit = 7.0701e+01 | forecast state err = 5.8520e-02 | analysis state err = 5.8402e-02 | gamma = 0.749 | ESS = 8.00/10 | resampled = False
# [assim @ step 97000] forecast obs misfit = 6.2098e+01 | analysis obs misfit = 6.2098e+01 | forecast state err = 6.2547e-02 | analysis state err = 6.2547e-02 | gamma = 1.000 | ESS = 9.86/10 | resampled = False
# Assim step 7000/10000 | drift err = 1.6700e-01 | analysis err = 6.2547e-02 | last gamma = 1.000 | last ESS = 9.86 | last resampled = False
# [assim @ step 97100] forecast obs misfit = 8.6110e+01 | analysis obs misfit = 7.4697e+01 | forecast state err = 6.9195e-02 | analysis state err = 6.6819e-02 | gamma = 0.151 | ESS = 8.00/10 | resampled = False
# [assim @ step 97200] forecast obs misfit = 6.3407e+01 | analysis obs misfit = 6.3407e+01 | forecast state err = 7.2992e-02 | analysis state err = 7.2992e-02 | gamma = 1.000 | ESS = 9.00/10 | resampled = False
# [assim @ step 97300] forecast obs misfit = 6.6136e+01 | analysis obs misfit = 6.5466e+01 | forecast state err = 7.8554e-02 | analysis state err = 7.8909e-02 | gamma = 0.971 | ESS = 8.00/10 | resampled = True
# [assim @ step 97400] forecast obs misfit = 7.3944e+01 | analysis obs misfit = 7.3944e+01 | forecast state err = 8.3556e-02 | analysis state err = 8.3556e-02 | gamma = 1.000 | ESS = 9.37/10 | resampled = False
# [assim @ step 97500] forecast obs misfit = 1.0194e+02 | analysis obs misfit = 9.3571e+01 | forecast state err = 8.8879e-02 | analysis state err = 8.7101e-02 | gamma = 0.124 | ESS = 8.00/10 | resampled = True
# Assim step 7500/10000 | drift err = 2.3399e-01 | analysis err = 8.7101e-02 | last gamma = 0.124 | last ESS = 8.00 | last resampled = True
# [assim @ step 97600] forecast obs misfit = 9.5552e+01 | analysis obs misfit = 9.4679e+01 | forecast state err = 8.9737e-02 | analysis state err = 8.9460e-02 | gamma = 0.574 | ESS = 8.00/10 | resampled = True
# [assim @ step 97700] forecast obs misfit = 8.6576e+01 | analysis obs misfit = 8.6541e+01 | forecast state err = 9.2802e-02 | analysis state err = 9.2769e-02 | gamma = 0.959 | ESS = 8.00/10 | resampled = False
# [assim @ step 97800] forecast obs misfit = 7.3171e+01 | analysis obs misfit = 7.2660e+01 | forecast state err = 9.7163e-02 | analysis state err = 9.6809e-02 | gamma = 0.550 | ESS = 8.00/10 | resampled = False
# [assim @ step 97900] forecast obs misfit = 1.1193e+02 | analysis obs misfit = 1.1126e+02 | forecast state err = 1.0106e-01 | analysis state err = 1.0112e-01 | gamma = 0.405 | ESS = 8.00/10 | resampled = False
# [assim @ step 98000] forecast obs misfit = 9.2908e+01 | analysis obs misfit = 9.2729e+01 | forecast state err = 1.0598e-01 | analysis state err = 1.0592e-01 | gamma = 0.742 | ESS = 8.00/10 | resampled = False
# Assim step 8000/10000 | drift err = 2.5811e-01 | analysis err = 1.0592e-01 | last gamma = 0.742 | last ESS = 8.00 | last resampled = False
# [assim @ step 98100] forecast obs misfit = 1.1945e+02 | analysis obs misfit = 1.0617e+02 | forecast state err = 1.1355e-01 | analysis state err = 1.0699e-01 | gamma = 0.127 | ESS = 8.00/10 | resampled = True
# [assim @ step 98200] forecast obs misfit = 1.1445e+02 | analysis obs misfit = 1.1346e+02 | forecast state err = 1.1664e-01 | analysis state err = 1.1543e-01 | gamma = 0.391 | ESS = 8.00/10 | resampled = False
# [assim @ step 98300] forecast obs misfit = 1.3566e+02 | analysis obs misfit = 1.3561e+02 | forecast state err = 1.2960e-01 | analysis state err = 1.2957e-01 | gamma = 0.894 | ESS = 8.00/10 | resampled = False
# [assim @ step 98400] forecast obs misfit = 1.1636e+02 | analysis obs misfit = 1.1575e+02 | forecast state err = 1.4384e-01 | analysis state err = 1.4413e-01 | gamma = 0.365 | ESS = 8.00/10 | resampled = False
# [assim @ step 98500] forecast obs misfit = 1.3809e+02 | analysis obs misfit = 1.2880e+02 | forecast state err = 1.5931e-01 | analysis state err = 1.6177e-01 | gamma = 0.142 | ESS = 8.00/10 | resampled = True
# Assim step 8500/10000 | drift err = 3.5387e-01 | analysis err = 1.6177e-01 | last gamma = 0.142 | last ESS = 8.00 | last resampled = True
# [assim @ step 98600] forecast obs misfit = 1.5579e+02 | analysis obs misfit = 1.4502e+02 | forecast state err = 1.7853e-01 | analysis state err = 1.7615e-01 | gamma = 0.096 | ESS = 8.00/10 | resampled = False
# [assim @ step 98700] forecast obs misfit = 1.6361e+02 | analysis obs misfit = 1.6326e+02 | forecast state err = 1.9670e-01 | analysis state err = 1.9632e-01 | gamma = 0.700 | ESS = 8.00/10 | resampled = True
# [assim @ step 98800] forecast obs misfit = 1.6451e+02 | analysis obs misfit = 1.6087e+02 | forecast state err = 2.1760e-01 | analysis state err = 2.1859e-01 | gamma = 0.164 | ESS = 8.00/10 | resampled = False
# [assim @ step 98900] forecast obs misfit = 1.2250e+02 | analysis obs misfit = 1.2233e+02 | forecast state err = 2.4093e-01 | analysis state err = 2.4062e-01 | gamma = 0.705 | ESS = 8.00/10 | resampled = False
# [assim @ step 99000] forecast obs misfit = 1.2910e+02 | analysis obs misfit = 1.2808e+02 | forecast state err = 2.6716e-01 | analysis state err = 2.6554e-01 | gamma = 0.467 | ESS = 8.00/10 | resampled = True
# Assim step 9000/10000 | drift err = 4.4502e-01 | analysis err = 2.6554e-01 | last gamma = 0.467 | last ESS = 8.00 | last resampled = True
# [assim @ step 99100] forecast obs misfit = 2.3911e+02 | analysis obs misfit = 2.3002e+02 | forecast state err = 2.8933e-01 | analysis state err = 2.8253e-01 | gamma = 0.109 | ESS = 8.00/10 | resampled = True
# [assim @ step 99200] forecast obs misfit = 2.7426e+02 | analysis obs misfit = 2.7211e+02 | forecast state err = 2.9753e-01 | analysis state err = 2.9576e-01 | gamma = 0.177 | ESS = 8.00/10 | resampled = True
# [assim @ step 99300] forecast obs misfit = 2.5687e+02 | analysis obs misfit = 2.5466e+02 | forecast state err = 3.0678e-01 | analysis state err = 3.0584e-01 | gamma = 0.214 | ESS = 8.00/10 | resampled = True
# [assim @ step 99400] forecast obs misfit = 1.9427e+02 | analysis obs misfit = 1.9427e+02 | forecast state err = 3.1963e-01 | analysis state err = 3.1963e-01 | gamma = 1.000 | ESS = 9.93/10 | resampled = False
# [assim @ step 99500] forecast obs misfit = 2.4751e+02 | analysis obs misfit = 2.4737e+02 | forecast state err = 3.3144e-01 | analysis state err = 3.3169e-01 | gamma = 0.865 | ESS = 8.00/10 | resampled = True
# Assim step 9500/10000 | drift err = 5.7408e-01 | analysis err = 3.3169e-01 | last gamma = 0.865 | last ESS = 8.00 | last resampled = True
# [assim @ step 99600] forecast obs misfit = 2.5279e+02 | analysis obs misfit = 2.5258e+02 | forecast state err = 3.3940e-01 | analysis state err = 3.3915e-01 | gamma = 0.722 | ESS = 8.00/10 | resampled = True
# [assim @ step 99700] forecast obs misfit = 2.6262e+02 | analysis obs misfit = 2.6262e+02 | forecast state err = 3.4693e-01 | analysis state err = 3.4693e-01 | gamma = 1.000 | ESS = 9.92/10 | resampled = False
# [assim @ step 99800] forecast obs misfit = 1.6682e+02 | analysis obs misfit = 1.6682e+02 | forecast state err = 3.5758e-01 | analysis state err = 3.5758e-01 | gamma = 1.000 | ESS = 9.51/10 | resampled = False
# [assim @ step 99900] forecast obs misfit = 1.8348e+02 | analysis obs misfit = 1.8348e+02 | forecast state err = 3.6865e-01 | analysis state err = 3.6865e-01 | gamma = 1.000 | ESS = 8.94/10 | resampled = False
# [assim @ step 100000] forecast obs misfit = 2.9488e+02 | analysis obs misfit = 2.9475e+02 | forecast state err = 3.8445e-01 | analysis state err = 3.8436e-01 | gamma = 0.611 | ESS = 8.00/10 | resampled = False
# Assim step 10000/10000 | drift err = 6.4032e-01 | analysis err = 3.8436e-01 | last gamma = 0.611 | last ESS = 8.00 | last resampled = False
# Assimilation run time: 440.54 s

# %%
# 4. Final vorticity fields
fig4, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

axes[0].contourf(X, Y, wen_truth, 100, cmap='RdBu_r')
axes[0].set_title("Truth final vorticity")
axes[0].set_aspect('equal')
axes[0].set_ylabel("y")
axes[0].set_xlabel("x")

axes[1].contourf(X, Y, np.abs(wen_truth-free_w), 100, cmap='hot')
axes[1].set_title("Drifted final vorticity")
axes[1].set_aspect('equal')
axes[1].set_xlabel("x")

axes[2].contourf(X, Y, np.abs(wen_truth-w_mean_final), 100, cmap='hot')
axes[2].set_title("EnKPF corrected final vorticity")
axes[2].set_aspect('equal')
axes[2].set_xlabel("x")

plt.tight_layout()

# 5. Final streamfunction fields
fig5, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

axes[0].contourf(X, Y, sen_truth, 100, cmap='viridis')
axes[0].set_title("Truth final streamfunction")
axes[0].set_aspect('equal')
axes[0].set_ylabel("y")
axes[0].set_xlabel("x")

axes[1].contourf(X, Y, np.abs(sen_truth-free_s), 100, cmap='hot')
axes[1].set_title("Drifted final streamfunction")
axes[1].set_aspect('equal')
axes[1].set_xlabel("x")

axes[2].contourf(X, Y, np.abs(sen_truth-s_mean_final), 100, cmap='hot')
axes[2].set_title("EnKPF corrected streamfunction")
axes[2].set_aspect('equal')
axes[2].set_xlabel("x")

plt.tight_layout()
